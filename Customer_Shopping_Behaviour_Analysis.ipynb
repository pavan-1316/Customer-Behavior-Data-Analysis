# %%
import pandas as pd
df = pd.read_csv("customer_shopping_behavior.csv")
df
# Out:
#            Customer ID          Age          Gender          Item Purchased  \
# 0                    1           22          Female                 T-shirt
# 1                    2           51            Male              Sunglasses
# 2                    3           18          Female                   Shirt
# 3                    4           22            Male                  Gloves
# 4                    5           40          Female                 Jewelry
# ...                ...          ...             ...                     ...
# 5046              5096           19          Female                Backpack
# 5047              5097           70          Female                   Skirt
# 5048              5098           43          Female                Sneakers
# 5049              5099           62            Male                  Blouse
# 5050  median(customer)  median(Age)  median(Gender)  median(Item Purchased)
#
#               Category  Purchase Amount (USD)          Location Size  \
# 0             Clothing                   68.0        California   XL
# 1          Accessories                   84.0    South Carolina    M
# 2             Clothing                   50.0           Montana    M
# 3          Accessories                   75.0          Illinois    L
# 4          Accessories                   80.0           Alabama    L
# ...                ...                    ...               ...  ...
# 5046       Accessories                   53.0              Iowa    M
# 5047          Clothing                   27.0      North Dakota    M
# 5048          Footwear                   52.0          Maryland    L
# 5049          Clothing                   71.0             Maine    M
# 5050  median(Category)                    0.0  median(Location)  NaN
#
#               Color          Season  Review Rating    Subscription Status  \
# 0             Olive          Winter             3.2                    No
# 1             White          Spring             3.9                   Yes
# 2             Black          Winter             3.1                    No
# 3               Red            Fall             4.2                    No
# 4            Yellow          Spring             3.6                    No
# ...             ...             ...             ...                   ...
# 5046           Gold          Spring             3.4                    No
# 5047          White          Summer             3.2                    No
# 5048           Gold          Summer             4.6                    No
# 5049           Cyan          Summer             3.3                    No
# 5050  median(Color)  median(Season)             0.0  median(Subscription)
#
#               Shipping Type          Discount Applied  Previous Purchases  \
# 0                  Standard                        No                  36
# 1             Free Shipping                       Yes                  20
# 2            2-Day Shipping                        No                  18
# 3              Store Pickup                        No                  25
# 4              Store Pickup                        No                  17
# ...                     ...                       ...                 ...
# 5046               Standard                        No                  31
# 5047               Standard                        No                  15
# 5048               Standard                        No                  10
# 5049          Free Shipping                        No                   5
# 5050  median(Shipping Type)  median(Discount Applied)                   0
#
#      Payment Method Frequency of Purchases
# 0              Cash                 Weekly
# 1        Debit Card              Quarterly
# 2              Cash                Monthly
# 3              Cash               Annually
# 4       Credit Card                 Weekly
# ...             ...                    ...
# 5046     Debit Card                 Weekly
# 5047  Bank Transfer         Every 3 Months
# 5048    Credit Card              Bi-Weekly
# 5049  Bank Transfer         Every 3 Months
# 5050   median(Cash)              Quarterly
#
# [5051 rows x 17 columns]

# %%
df.shape
# Out:
# (5051, 17)

# %%
df.head()
# Out:
#   Customer ID Age  Gender Item Purchased     Category  Purchase Amount (USD)  \
# 0           1  22  Female        T-shirt     Clothing                   68.0
# 1           2  51    Male     Sunglasses  Accessories                   84.0
# 2           3  18  Female          Shirt     Clothing                   50.0
# 3           4  22    Male         Gloves  Accessories                   75.0
# 4           5  40  Female        Jewelry  Accessories                   80.0
#
#          Location Size   Color  Season  Review Rating  Subscription Status  \
# 0      California   XL   Olive  Winter             3.2                  No
# 1  South Carolina    M   White  Spring             3.9                 Yes
# 2         Montana    M   Black  Winter             3.1                  No
# 3        Illinois    L     Red    Fall             4.2                  No
# 4         Alabama    L  Yellow  Spring             3.6                  No
#
#     Shipping Type Discount Applied  Previous Purchases Payment Method  \
# 0        Standard               No                  36           Cash
# 1   Free Shipping              Yes                  20     Debit Card
# 2  2-Day Shipping               No                  18           Cash
# 3    Store Pickup               No                  25           Cash
# 4    Store Pickup               No                  17    Credit Card
#
#   Frequency of Purchases
# 0                 Weekly
# 1              Quarterly
# 2                Monthly
# 3               Annually
# 4                 Weekly

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5051 entries, 0 to 5050
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             5051 non-null   object
#  1   Age                     5051 non-null   object
#  2   Gender                  5051 non-null   object
#  3   Item Purchased          5051 non-null   object
#  4   Category                5051 non-null   object
#  5   Purchase Amount (USD)   5051 non-null   float64
#  6   Location                5051 non-null   object
#  7   Size                    4680 non-null   object
#  8   Color                   5051 non-null   object
#  9   Season                  5051 non-null   object
#  10  Review Rating           5051 non-null   float64
#  11  Subscription Status     5051 non-null   object
#  12  Shipping Type           5051 non-null   object
#  13  Discount Applied        5051 non-null   object
#  14  Previous Purchases      5051 non-null   int64
#  15  Payment Method          5051 non-null   object
#  16  Frequency of Purchases  5051 non-null   object
# dtypes: float64(2), int64(1), object(14)
# memory usage: 671.0+ KB

# %%
df.describe(include="all")
# Out:
#        Customer ID   Age Gender Item Purchased  Category  \
# count         5051  5051   5051           5051      5051
# unique        5001    54      4             31         6
# top           3507    41   Male          Shirt  Clothing
# freq             2   114   3018            320      2130
# mean           NaN   NaN    NaN            NaN       NaN
# std            NaN   NaN    NaN            NaN       NaN
# min            NaN   NaN    NaN            NaN       NaN
# 25%            NaN   NaN    NaN            NaN       NaN
# 50%            NaN   NaN    NaN            NaN       NaN
# 75%            NaN   NaN    NaN            NaN       NaN
# max            NaN   NaN    NaN            NaN       NaN
#
#         Purchase Amount (USD)  Location  Size  Color  Season  Review Rating   \
# count             5051.000000      5051  4680   5051    5051     5051.000000
# unique                    NaN        55     4     26       6             NaN
# top                       NaN  New York     M  Black  Spring             NaN
# freq                      NaN       337  1981    404    1280             NaN
# mean               128.801222       NaN   NaN    NaN     NaN        3.231004
# std                263.873922       NaN   NaN    NaN     NaN        1.439590
# min                  0.000000       NaN   NaN    NaN     NaN        0.000000
# 25%                 33.000000       NaN   NaN    NaN     NaN        2.800000
# 50%                 59.000000       NaN   NaN    NaN     NaN        3.500000
# 75%                 85.000000       NaN   NaN    NaN     NaN        4.300000
# max               1499.760000       NaN   NaN    NaN     NaN        5.000000
#
#        Subscription Status Shipping Type Discount Applied  Previous Purchases  \
# count                 5051          5051             5051         5051.000000
# unique                   3             7                3                 NaN
# top                     No      Standard               No                 NaN
# freq                  3462          1213             2789                 NaN
# mean                   NaN           NaN              NaN           22.480499
# std                    NaN           NaN              NaN           15.798514
# min                    NaN           NaN              NaN            0.000000
# 25%                    NaN           NaN              NaN            8.000000
# 50%                    NaN           NaN              NaN           22.000000
# 75%                    NaN           NaN              NaN           36.000000
# max                    NaN           NaN              NaN           50.000000
#
#        Payment Method Frequency of Purchases
# count            5051                   5051
# unique              7                      7
# top       Credit Card                Monthly
# freq              954                    946
# mean              NaN                    NaN
# std               NaN                    NaN
# min               NaN                    NaN
# 25%               NaN                    NaN
# 50%               NaN                    NaN
# 75%               NaN                    NaN
# max               NaN                    NaN

# %%
df.isnull().sum()
# Out:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)       0
# Location                    0
# Size                      371
# Color                       0
# Season                      0
# Review Rating               0
# Subscription Status         0
# Shipping Type               0
# Discount Applied            0
# Previous Purchases          0
# Payment Method              0
# Frequency of Purchases      0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['Size'] = le.fit_transform(df['Size'])

# %%
df['Size'] = df.groupby('Category')['Size'].transform(lambda x: x.fillna(x.median()))

# %%
df.isnull().sum()
# Out:
# Customer ID               0
# Age                       0
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount (USD)     0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review Rating             0
# Subscription Status       0
# Shipping Type             0
# Discount Applied          0
# Previous Purchases        0
# Payment Method            0
# Frequency of Purchases    0
# dtype: int64

# %%
df
# Out:
#            Customer ID          Age          Gender          Item Purchased  \
# 0                    1           22          Female                 T-shirt
# 1                    2           51            Male              Sunglasses
# 2                    3           18          Female                   Shirt
# 3                    4           22            Male                  Gloves
# 4                    5           40          Female                 Jewelry
# ...                ...          ...             ...                     ...
# 5046              5096           19          Female                Backpack
# 5047              5097           70          Female                   Skirt
# 5048              5098           43          Female                Sneakers
# 5049              5099           62            Male                  Blouse
# 5050  median(customer)  median(Age)  median(Gender)  median(Item Purchased)
#
#               Category  Purchase Amount (USD)          Location  Size  \
# 0             Clothing                   68.0        California     3
# 1          Accessories                   84.0    South Carolina     1
# 2             Clothing                   50.0           Montana     1
# 3          Accessories                   75.0          Illinois     0
# 4          Accessories                   80.0           Alabama     0
# ...                ...                    ...               ...   ...
# 5046       Accessories                   53.0              Iowa     1
# 5047          Clothing                   27.0      North Dakota     1
# 5048          Footwear                   52.0          Maryland     0
# 5049          Clothing                   71.0             Maine     1
# 5050  median(Category)                    0.0  median(Location)     4
#
#               Color          Season  Review Rating    Subscription Status  \
# 0             Olive          Winter             3.2                    No
# 1             White          Spring             3.9                   Yes
# 2             Black          Winter             3.1                    No
# 3               Red            Fall             4.2                    No
# 4            Yellow          Spring             3.6                    No
# ...             ...             ...             ...                   ...
# 5046           Gold          Spring             3.4                    No
# 5047          White          Summer             3.2                    No
# 5048           Gold          Summer             4.6                    No
# 5049           Cyan          Summer             3.3                    No
# 5050  median(Color)  median(Season)             0.0  median(Subscription)
#
#               Shipping Type          Discount Applied  Previous Purchases  \
# 0                  Standard                        No                  36
# 1             Free Shipping                       Yes                  20
# 2            2-Day Shipping                        No                  18
# 3              Store Pickup                        No                  25
# 4              Store Pickup                        No                  17
# ...                     ...                       ...                 ...
# 5046               Standard                        No                  31
# 5047               Standard                        No                  15
# 5048               Standard                        No                  10
# 5049          Free Shipping                        No                   5
# 5050  median(Shipping Type)  median(Discount Applied)                   0
#
#      Payment Method Frequency of Purchases
# 0              Cash                 Weekly
# 1        Debit Card              Quarterly
# 2              Cash                Monthly
# 3              Cash               Annually
# 4       Credit Card                 Weekly
# ...             ...                    ...
# 5046     Debit Card                 Weekly
# 5047  Bank Transfer         Every 3 Months
# 5048    Credit Card              Bi-Weekly
# 5049  Bank Transfer         Every 3 Months
# 5050   median(Cash)              Quarterly
#
# [5051 rows x 17 columns]

# %%
df.columns = df.columns.str.lower()
df.columns = df.columns.str.replace(' ','_')

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount_(usd)', 'location', 'size', 'color', 'season',
#        'review_rating_', 'subscription_status', 'shipping_type',
#        'discount_applied', 'previous_purchases', 'payment_method',
#        'frequency_of_purchases'],
#       dtype='object')

# %%
df = df.rename(columns = {'purchase_amount_(usd)':'Purchased_Amount'})

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'Purchased_Amount', 'location', 'size', 'color', 'season',
#        'review_rating_', 'subscription_status', 'shipping_type',
#        'discount_applied', 'previous_purchases', 'payment_method',
#        'frequency_of_purchases'],
#       dtype='object')

# %%
df
# Out:
#            customer_id          age          gender          item_purchased  \
# 0                    1           22          Female                 T-shirt
# 1                    2           51            Male              Sunglasses
# 2                    3           18          Female                   Shirt
# 3                    4           22            Male                  Gloves
# 4                    5           40          Female                 Jewelry
# ...                ...          ...             ...                     ...
# 5046              5096           19          Female                Backpack
# 5047              5097           70          Female                   Skirt
# 5048              5098           43          Female                Sneakers
# 5049              5099           62            Male                  Blouse
# 5050  median(customer)  median(Age)  median(Gender)  median(Item Purchased)
#
#               category  Purchased_Amount          location  size  \
# 0             Clothing              68.0        California     3
# 1          Accessories              84.0    South Carolina     1
# 2             Clothing              50.0           Montana     1
# 3          Accessories              75.0          Illinois     0
# 4          Accessories              80.0           Alabama     0
# ...                ...               ...               ...   ...
# 5046       Accessories              53.0              Iowa     1
# 5047          Clothing              27.0      North Dakota     1
# 5048          Footwear              52.0          Maryland     0
# 5049          Clothing              71.0             Maine     1
# 5050  median(Category)               0.0  median(Location)     4
#
#               color          season  review_rating_   subscription_status  \
# 0             Olive          Winter             3.2                    No
# 1             White          Spring             3.9                   Yes
# 2             Black          Winter             3.1                    No
# 3               Red            Fall             4.2                    No
# 4            Yellow          Spring             3.6                    No
# ...             ...             ...             ...                   ...
# 5046           Gold          Spring             3.4                    No
# 5047          White          Summer             3.2                    No
# 5048           Gold          Summer             4.6                    No
# 5049           Cyan          Summer             3.3                    No
# 5050  median(Color)  median(Season)             0.0  median(Subscription)
#
#               shipping_type          discount_applied  previous_purchases  \
# 0                  Standard                        No                  36
# 1             Free Shipping                       Yes                  20
# 2            2-Day Shipping                        No                  18
# 3              Store Pickup                        No                  25
# 4              Store Pickup                        No                  17
# ...                     ...                       ...                 ...
# 5046               Standard                        No                  31
# 5047               Standard                        No                  15
# 5048               Standard                        No                  10
# 5049          Free Shipping                        No                   5
# 5050  median(Shipping Type)  median(Discount Applied)                   0
#
#      payment_method frequency_of_purchases
# 0              Cash                 Weekly
# 1        Debit Card              Quarterly
# 2              Cash                Monthly
# 3              Cash               Annually
# 4       Credit Card                 Weekly
# ...             ...                    ...
# 5046     Debit Card                 Weekly
# 5047  Bank Transfer         Every 3 Months
# 5048    Credit Card              Bi-Weekly
# 5049  Bank Transfer         Every 3 Months
# 5050   median(Cash)              Quarterly
#
# [5051 rows x 17 columns]

# %%
#create a column age_group
labels = ['Young Adult', 'Adult', 'Middle-aged', 'Senior']

df['age_group'] = pd.qcut(
    df['age'],
    q=4,
    labels=labels
)

# %%
df['age'] = pd.to_numeric(df['age'], errors='coerce')

# %%
print(df['age'].dtype)
# Out:
# float64

# %%
df
# Out:
#            customer_id   age          gender          item_purchased  \
# 0                    1  22.0          Female                 T-shirt
# 1                    2  51.0            Male              Sunglasses
# 2                    3  18.0          Female                   Shirt
# 3                    4  22.0            Male                  Gloves
# 4                    5  40.0          Female                 Jewelry
# ...                ...   ...             ...                     ...
# 5046              5096  19.0          Female                Backpack
# 5047              5097  70.0          Female                   Skirt
# 5048              5098  43.0          Female                Sneakers
# 5049              5099  62.0            Male                  Blouse
# 5050  median(customer)   NaN  median(Gender)  median(Item Purchased)
#
#               category  Purchased_Amount          location  size  \
# 0             Clothing              68.0        California     3
# 1          Accessories              84.0    South Carolina     1
# 2             Clothing              50.0           Montana     1
# 3          Accessories              75.0          Illinois     0
# 4          Accessories              80.0           Alabama     0
# ...                ...               ...               ...   ...
# 5046       Accessories              53.0              Iowa     1
# 5047          Clothing              27.0      North Dakota     1
# 5048          Footwear              52.0          Maryland     0
# 5049          Clothing              71.0             Maine     1
# 5050  median(Category)               0.0  median(Location)     4
#
#               color          season  review_rating_   subscription_status  \
# 0             Olive          Winter             3.2                    No
# 1             White          Spring             3.9                   Yes
# 2             Black          Winter             3.1                    No
# 3               Red            Fall             4.2                    No
# 4            Yellow          Spring             3.6                    No
# ...             ...             ...             ...                   ...
# 5046           Gold          Spring             3.4                    No
# 5047          White          Summer             3.2                    No
# 5048           Gold          Summer             4.6                    No
# 5049           Cyan          Summer             3.3                    No
# 5050  median(Color)  median(Season)             0.0  median(Subscription)
#
#               shipping_type          discount_applied  previous_purchases  \
# 0                  Standard                        No                  36
# 1             Free Shipping                       Yes                  20
# 2            2-Day Shipping                        No                  18
# 3              Store Pickup                        No                  25
# 4              Store Pickup                        No                  17
# ...                     ...                       ...                 ...
# 5046               Standard                        No                  31
# 5047               Standard                        No                  15
# 5048               Standard                        No                  10
# 5049          Free Shipping                        No                   5
# 5050  median(Shipping Type)  median(Discount Applied)                   0
#
#      payment_method frequency_of_purchases    age_group
# 0              Cash                 Weekly  Young Adult
# 1        Debit Card              Quarterly  Middle-aged
# 2              Cash                Monthly  Young Adult
# 3              Cash               Annually  Young Adult
# 4       Credit Card                 Weekly        Adult
# ...             ...                    ...          ...
# 5046     Debit Card                 Weekly  Young Adult
# 5047  Bank Transfer         Every 3 Months       Senior
# 5048    Credit Card              Bi-Weekly        Adult
# 5049  Bank Transfer         Every 3 Months       Senior
# 5050   median(Cash)              Quarterly          NaN
#
# [5051 rows x 18 columns]

# %%
frequency_days = {
    'Weekly': 7,
    'Bi-Weekly': 14,
    'Fortnightly': 14,
    'Monthly': 30,
    'Quarterly': 90,
    'Every 3 Months': 90,
    'Annually': 365
}

df['purchase_frequency_days'] = df['frequency_of_purchases'].map(frequency_days)

# %%
df['frequency_of_purchases'].head(10)
# Out:
# 0            Weekly
# 1         Quarterly
# 2           Monthly
# 3          Annually
# 4            Weekly
# 5          Annually
# 6    Every 3 Months
# 7          Annually
# 8         Bi-Weekly
# 9           Monthly
# Name: frequency_of_purchases, dtype: object

# %%
df
# Out:
#            customer_id   age          gender          item_purchased  \
# 0                    1  22.0          Female                 T-shirt
# 1                    2  51.0            Male              Sunglasses
# 2                    3  18.0          Female                   Shirt
# 3                    4  22.0            Male                  Gloves
# 4                    5  40.0          Female                 Jewelry
# ...                ...   ...             ...                     ...
# 5046              5096  19.0          Female                Backpack
# 5047              5097  70.0          Female                   Skirt
# 5048              5098  43.0          Female                Sneakers
# 5049              5099  62.0            Male                  Blouse
# 5050  median(customer)   NaN  median(Gender)  median(Item Purchased)
#
#               category  Purchased_Amount          location  size  \
# 0             Clothing              68.0        California     3
# 1          Accessories              84.0    South Carolina     1
# 2             Clothing              50.0           Montana     1
# 3          Accessories              75.0          Illinois     0
# 4          Accessories              80.0           Alabama     0
# ...                ...               ...               ...   ...
# 5046       Accessories              53.0              Iowa     1
# 5047          Clothing              27.0      North Dakota     1
# 5048          Footwear              52.0          Maryland     0
# 5049          Clothing              71.0             Maine     1
# 5050  median(Category)               0.0  median(Location)     4
#
#               color          season  review_rating_   subscription_status  \
# 0             Olive          Winter             3.2                    No
# 1             White          Spring             3.9                   Yes
# 2             Black          Winter             3.1                    No
# 3               Red            Fall             4.2                    No
# 4            Yellow          Spring             3.6                    No
# ...             ...             ...             ...                   ...
# 5046           Gold          Spring             3.4                    No
# 5047          White          Summer             3.2                    No
# 5048           Gold          Summer             4.6                    No
# 5049           Cyan          Summer             3.3                    No
# 5050  median(Color)  median(Season)             0.0  median(Subscription)
#
#               shipping_type          discount_applied  previous_purchases  \
# 0                  Standard                        No                  36
# 1             Free Shipping                       Yes                  20
# 2            2-Day Shipping                        No                  18
# 3              Store Pickup                        No                  25
# 4              Store Pickup                        No                  17
# ...                     ...                       ...                 ...
# 5046               Standard                        No                  31
# 5047               Standard                        No                  15
# 5048               Standard                        No                  10
# 5049          Free Shipping                        No                   5
# 5050  median(Shipping Type)  median(Discount Applied)                   0
#
#      payment_method frequency_of_purchases    age_group  \
# 0              Cash                 Weekly  Young Adult
# 1        Debit Card              Quarterly  Middle-aged
# 2              Cash                Monthly  Young Adult
# 3              Cash               Annually  Young Adult
# 4       Credit Card                 Weekly        Adult
# ...             ...                    ...          ...
# 5046     Debit Card                 Weekly  Young Adult
# 5047  Bank Transfer         Every 3 Months       Senior
# 5048    Credit Card              Bi-Weekly        Adult
# 5049  Bank Transfer         Every 3 Months       Senior
# 5050   median(Cash)              Quarterly          NaN
#
#       purchase_frequency_days
# 0                           7
# 1                          90
# 2                          30
# 3                         365
# 4                           7
# ...                       ...
# 5046                        7
# 5047                       90
# 5048                       14
# 5049                       90
# 5050                       90
#
# [5051 rows x 19 columns]

# %%
from sqlalchemy import create_engine

# Step 1: Connect to PostgreSQL
# Replace placeholders with your actual details
username = "postgres"      # default user
password = "Pavan28126"     # the password you set during installation
host = "localhost"        # if running locally
port = "5432"             # default PostgreSQL port
database = "customer_behaviour"     # the database you created in pgAdmin

engine = create_engine(f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}")

# Step 2: Load DataFrame into PostgreSQL
table_name = "customer"    # choose any table name
df.to_sql(table_name, engine, if_exists="replace", index=False)

print(f"Data successfully loaded into table '{table_name}' in database '{database}'.")
# Out:
# Data successfully loaded into table 'customer' in database 'customer_behaviour'.
